# %% [markdown]
# Nota: Esta solo es para ejemplificar el codigo todo esta ejecutado en terminal de Mac

# %%
from openai import OpenAI

client = OpenAI(
    api_key="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"
# API  fue removida por seguridad del panel de administración de  OpenIA
)

MODEL = "gpt-4.1-mini"

print(f"\nChatting with {MODEL}\n")

messages = []

while True:

    prompt = input("> ")

    if prompt.lower() == "salir":
        break

    # Mensaje guardados
    messages.append({
        "role": "user",
        "content": prompt
    })

    # Conexion al modelo
    response = client.chat.completions.create(
        model=MODEL,
        messages=messages
    )

    # Respuesta
    reply = response.choices[0].message.content

    # Mostrar
    print(reply)
    print()

    # Guardar respuesta del asistente
    messages.append({
        "role": "assistant",
        "content": reply
    })

# %% [markdown]
# ![Screenshot 2026-05-13 at 10.15.15 AM.png](data:image/png;base64,...)
